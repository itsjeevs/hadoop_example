# %%
#!/usr/bin/python
import sys


class GameResult:
    def __init__(self, score):
        self.score = score
        self.process()

    def process(self):
        home, away = self.score.split("-")

        self.home_goals = int(home.split(" ")[-1])
        self.home_team = " ".join(home.split(" ")[:-1]).strip()

        self.away_goals = int(away.split(" ")[0])
        self.away_team = " ".join(away.split(" ")[1:]).strip()

        self.home_goal_diff = self.home_goals - self.away_goals
        self.away_goal_diff = -self.home_goal_diff

        if self.home_goals > self.away_goals:
            self.home_winner = "1"
            self.away_winner = "0"
            self.is_draw = "0"
            self.home_points = "3"
            self.away_points = "0"
        elif self.home_goals < self.away_goals:
            self.home_winner = "0"
            self.away_winner = "1"
            self.is_draw = "0"
            self.home_points = "0"
            self.away_points = "3"
        else:
            self.home_points = "1"
            self.away_points = "1"
            self.is_draw = "1"
            self.home_winner = "0"
            self.away_winner = "0"

    def __str__(self):
        return "\n".join(
            ["\t".join(
                [self.home_team, "home", self.home_winner, self.is_draw, self.away_winner, str(self.home_goals),
                    str(self.away_goals), self.home_points]),
            "\t".join(
                [self.away_team, "away", self.away_winner, self.is_draw, self.home_winner, str(self.away_goals),
                    str(self.home_goals), self.away_points])])


valid_lines = []
for line in open("epl_data.txt", "r"):
# for line in sys.stdin:
    if "*" in line:
        valid_lines.append(line.replace("*", "").strip())

for line in valid_lines:
    a_game = GameResult(line)
    print a_game
# Out:
# Manchester United	home	1	0	0	1	0	3
# Tottenham Hotspur	away	0	0	1	0	1	0
# AFC Bournemouth	home	0	0	1	0	1	0
# Aston Villa	away	1	0	0	1	0	3
# Everton FC	home	0	1	0	2	2	1
# Watford FC	away	0	1	0	2	2	1
# Leicester City	home	1	0	0	4	2	3
# Sunderland AFC	away	0	0	1	2	4	0
# Norwich City	home	0	0	1	1	3	0
# Crystal Palace	away	1	0	0	3	1	3
# Chelsea FC	home	0	1	0	2	2	1
# Swansea City	away	0	1	0	2	2	1
# Arsenal FC	home	0	0	1	0	2	0
# West Ham United	away	1	0	0	2	0	3
# Newcastle United	home	0	1	0	2	2	1
# Southampton FC	away	0	1	0	2	2	1
# Stoke City	home	0	0	1	0	1	0
# Liverpool FC	away	1	0	0	1	0	3
# West Bromwich Albion	home	0	0	1	0	3	0
# Manchester City	away	1	0	0	3	0	3
# Aston Villa	home	0	0	1	0	1	0
# Manchester United	away	1	0	0	1	0	3
# Southampton FC	home	0	0	1	0	3	0
# Everton FC	away	1	0	0	3	0	3
# Sunderland AFC	home	0	0	1	1	3	0
# Norwich City	away	1	0	0	3	1	3
# Swansea City	home	1	0	0	2	0	3
# Newcastle United	away	0	0	1	0	2	0
# Tottenham Hotspur	home	0	1	0	2	2	1
# Stoke City	away	0	1	0	2	2	1
# Watford FC	home	0	1	0	0	0	1
# West Bromwich Albion	away	0	1	0	0	0	1
# West Ham United	home	0	0	1	1	2	0
# Leicester City	away	1	0	0	2	1	3
# Crystal Palace	home	0	0	1	1	2	0
# Arsenal FC	away	1	0	0	2	1	3
# Manchester City	home	1	0	0	3	0	3
# Chelsea FC	away	0	0	1	0	3	0
# Liverpool FC	home	1	0	0	1	0	3
# AFC Bournemouth	away	0	0	1	0	1	0
# Manchester United	home	0	1	0	0	0	1
# Newcastle United	away	0	1	0	0	0	1
# Crystal Palace	home	1	0	0	2	1	3
# Aston Villa	away	0	0	1	1	2	0
# Leicester City	home	0	1	0	1	1	1
# Tottenham Hotspur	away	0	1	0	1	1	1
# Norwich City	home	0	1	0	1	1	1
# Stoke City	away	0	1	0	1	1	1
# Sunderland AFC	home	0	1	0	1	1	1
# Swansea City	away	0	1	0	1	1	1
# West Ham United	home	0	0	1	3	4	0
# AFC Bournemouth	away	1	0	0	4	3	3
# West Bromwich Albion	home	0	0	1	2	3	0
# Chelsea FC	away	1	0	0	3	2	3
# Everton FC	home	0	0	1	0	2	0
# Manchester City	away	1	0	0	2	0	3
# Watford FC	home	0	1	0	0	0	1
# Southampton FC	away	0	1	0	0	0	1
# Arsenal FC	home	0	1	0	0	0	1
# Liverpool FC	away	0	1	0	0	0	1
# Newcastle United	home	0	0	1	0	1	0
# Arsenal FC	away	1	0	0	1	0	3
# AFC Bournemouth	home	0	1	0	1	1	1
# Leicester City	away	0	1	0	1	1	1
# Aston Villa	home	0	1	0	2	2	1
# Sunderland AFC	away	0	1	0	2	2	1
# Chelsea FC	home	0	0	1	1	2	0
# Crystal Palace	away	1	0	0	2	1	3
# Liverpool FC	home	0	0	1	0	3	0
# West Ham United	away	1	0	0	3	0	3
# Manchester City	home	1	0	0	2	0	3
# Watford FC	away	0	0	1	0	2	0
# Stoke City	home	0	0	1	0	1	0
# West Bromwich Albion	away	1	0	0	1	0	3
# Tottenham Hotspur	home	0	1	0	0	0	1
# Everton FC	away	0	1	0	0	0	1
# Southampton FC	home	1	0	0	3	0	3
# Norwich City	away	0	0	1	0	3	0
# Swansea City	home	1	0	0	2	1	3
# Manchester United	away	0	0	1	1	2	0
# Everton FC	home	1	0	0	3	1	3
# Chelsea FC	away	0	0	1	1	3	0
# Arsenal FC	home	1	0	0	2	0	3
# Stoke City	away	0	0	1	0	2	0
# Crystal Palace	home	0	0	1	0	1	0
# Manchester City	away	1	0	0	1	0	3
# Norwich City	home	1	0	0	3	1	3
# AFC Bournemouth	away	0	0	1	1	3	0
# Watford FC	home	1	0	0	1	0	3
# Swansea City	away	0	0	1	0	1	0
# West Bromwich Albion	home	0	1	0	0	0	1
# Southampton FC	away	0	1	0	0	0	1
# Manchester United	home	1	0	0	3	1	3
# Liverpool FC	away	0	0	1	1	3	0
# Sunderland AFC	home	0	0	1	0	1	0
# Tottenham Hotspur	away	1	0	0	1	0	3
# Leicester City	home	1	0	0	3	2	3
# Aston Villa	away	0	0	1	2	3	0
# West Ham United	home	1	0	0	2	0	3
# Newcastle United	away	0	0	1	0	2	0
# Chelsea FC	home	1	0	0	2	0	3
# Arsenal FC	away	0	0	1	0	2	0
# AFC Bournemouth	home	1	0	0	2	0	3
# Sunderland AFC	away	0	0	1	0	2	0
# Aston Villa	home	0	0	1	0	1	0
# West Bromwich Albion	away	1	0	0	1	0	3
# Newcastle United	home	0	0	1	1	2	0
# Watford FC	away	1	0	0	2	1	3
# Stoke City	home	0	1	0	2	2	1
# Leicester City	away	0	1	0	2	2	1
# Swansea City	home	0	1	0	0	0	1
# Everton FC	away	0	1	0	0	0	1
# Manchester City	home	0	0	1	1	2	0
# West Ham United	away	1	0	0	2	1	3
# Tottenham Hotspur	home	1	0	0	1	0	3
# Crystal Palace	away	0	0	1	0	1	0
# Liverpool FC	home	0	1	0	1	1	1
# Norwich City	away	0	1	0	1	1	1
# Southampton FC	home	0	0	1	2	3	0
# Manchester United	away	1	0	0	3	2	3
# Tottenham Hotspur	home	1	0	0	4	1	3
# Manchester City	away	0	0	1	1	4	0
# Leicester City	home	0	0	1	2	5	0
# Arsenal FC	away	1	0	0	5	2	3
# Liverpool FC	home	1	0	0	3	2	3
# Aston Villa	away	0	0	1	2	3	0
# Manchester United	home	1	0	0	3	0	3
# Sunderland AFC	away	0	0	1	0	3	0
# Southampton FC	home	1	0	0	3	1	3
# Swansea City	away	0	0	1	1	3	0
# Stoke City	home	1	0	0	2	1	3
# AFC Bournemouth	away	0	0	1	1	2	0
# West Ham United	home	0	1	0	2	2	1
# Norwich City	away	0	1	0	2	2	1
# Newcastle United	home	0	1	0	2	2	1
# Chelsea FC	away	0	1	0	2	2	1
# Watford FC	home	0	0	1	0	1	0
# Crystal Palace	away	1	0	0	1	0	3
# West Bromwich Albion	home	0	0	1	2	3	0
# Everton FC	away	1	0	0	3	2	3
# AFC Bournemouth	home	0	1	0	1	1	1
# Watford FC	away	0	1	0	1	1	1
# Arsenal FC	home	1	0	0	3	0	3
# Manchester United	away	0	0	1	0	3	0
# Aston Villa	home	0	0	1	0	1	0
# Stoke City	away	1	0	0	1	0	3
# Chelsea FC	home	0	0	1	1	3	0
# Southampton FC	away	1	0	0	3	1	3
# Crystal Palace	home	1	0	0	2	0	3
# West Bromwich Albion	away	0	0	1	0	2	0
# Everton FC	home	0	1	0	1	1	1
# Liverpool FC	away	0	1	0	1	1	1
# Manchester City	home	1	0	0	6	1	3
# Newcastle United	away	0	0	1	1	6	0
# Norwich City	home	0	0	1	1	2	0
# Leicester City	away	1	0	0	2	1	3
# Sunderland AFC	home	0	1	0	2	2	1
# West Ham United	away	0	1	0	2	2	1
# Swansea City	home	0	1	0	2	2	1
# Tottenham Hotspur	away	0	1	0	2	2	1
# Chelsea FC	home	1	0	0	2	0	3
# Aston Villa	away	0	0	1	0	2	0
# Crystal Palace	home	0	0	1	1	3	0
# West Ham United	away	1	0	0	3	1	3
# Everton FC	home	0	0	1	0	3	0
# Manchester United	away	1	0	0	3	0	3
# Manchester City	home	1	0	0	5	1	3
# AFC Bournemouth	away	0	0	1	1	5	0
# Newcastle United	home	1	0	0	6	2	3
# Norwich City	away	0	0	1	2	6	0
# Southampton FC	home	0	1	0	2	2	1
# Leicester City	away	0	1	0	2	2	1
# Swansea City	home	0	0	1	0	1	0
# Stoke City	away	1	0	0	1	0	3
# Tottenham Hotspur	home	0	1	0	0	0	1
# Liverpool FC	away	0	1	0	0	0	1
# Watford FC	home	0	0	1	0	3	0
# Arsenal FC	away	1	0	0	3	0	3
# West Bromwich Albion	home	1	0	0	1	0	3
# Sunderland AFC	away	0	0	1	0	1	0
# AFC Bournemouth	home	0	0	1	1	5	0
# Tottenham Hotspur	away	1	0	0	5	1	3
# Arsenal FC	home	1	0	0	2	1	3
# Everton FC	away	0	0	1	1	2	0
# Aston Villa	home	0	0	1	1	2	0
# Swansea City	away	1	0	0	2	1	3
# Leicester City	home	1	0	0	1	0	3
# Crystal Palace	away	0	0	1	0	1	0
# Liverpool FC	home	0	1	0	1	1	1
# Southampton FC	away	0	1	0	1	1	1
# Manchester United	home	0	1	0	0	0	1
# Manchester City	away	0	1	0	0	0	1
# Norwich City	home	0	0	1	0	1	0
# West Bromwich Albion	away	1	0	0	1	0	3
# Stoke City	home	0	0	1	0	2	0
# Watford FC	away	1	0	0	2	0	3
# Sunderland AFC	home	1	0	0	3	0	3
# Newcastle United	away	0	0	1	0	3	0
# West Ham United	home	1	0	0	2	1	3
# Chelsea FC	away	0	0	1	1	2	0
# Chelsea FC	home	0	0	1	1	3	0
# Liverpool FC	away	1	0	0	3	1	3
# Crystal Palace	home	0	1	0	0	0	1
# Manchester United	away	0	1	0	0	0	1
# Everton FC	home	1	0	0	6	2	3
# Sunderland AFC	away	0	0	1	2	6	0
# Manchester City	home	1	0	0	2	1	3
# Norwich City	away	0	0	1	1	2	0
# Newcastle United	home	0	1	0	0	0	1
# Stoke City	away	0	1	0	0	0	1
# Southampton FC	home	1	0	0	2	0	3
# AFC Bournemouth	away	0	0	1	0	2	0
# Swansea City	home	0	0	1	0	3	0
# Arsenal FC	away	1	0	0	3	0	3
# Tottenham Hotspur	home	1	0	0	3	1	3
# Aston Villa	away	0	0	1	1	3	0
# Watford FC	home	1	0	0	2	0	3
# West Ham United	away	0	0	1	0	2	0
# West Bromwich Albion	home	0	0	1	2	3	0
# Leicester City	away	1	0	0	3	2	3
# AFC Bournemouth	home	0	0	1	0	1	0
# Newcastle United	away	1	0	0	1	0	3
# Arsenal FC	home	0	1	0	1	1	1
# Tottenham Hotspur	away	0	1	0	1	1	1
# Aston Villa	home	0	1	0	0	0	1
# Manchester City	away	0	1	0	0	0	1
# Leicester City	home	1	0	0	2	1	3
# Watford FC	away	0	0	1	1	2	0
# Liverpool FC	home	0	0	1	1	2	0
# Crystal Palace	away	1	0	0	2	1	3
# Manchester United	home	1	0	0	2	0	3
# West Bromwich Albion	away	0	0	1	0	2	0
# Norwich City	home	1	0	0	1	0	3
# Swansea City	away	0	0	1	0	1	0
# Stoke City	home	1	0	0	1	0	3
# Chelsea FC	away	0	0	1	0	1	0
# Sunderland AFC	home	0	0	1	0	1	0
# Southampton FC	away	1	0	0	1	0	3
# West Ham United	home	0	1	0	1	1	1
# Everton FC	away	0	1	0	1	1	1
# Chelsea FC	home	1	0	0	1	0	3
# Norwich City	away	0	0	1	0	1	0
# Crystal Palace	home	0	0	1	0	1	0
# Sunderland AFC	away	1	0	0	1	0	3
# Everton FC	home	1	0	0	4	0	3
# Aston Villa	away	0	0	1	0	4	0
# Manchester City	home	0	0	1	1	4	0
# Liverpool FC	away	1	0	0	4	1	3
# Newcastle United	home	0	0	1	0	3	0
# Leicester City	away	1	0	0	3	0	3
# Southampton FC	home	0	0	1	0	1	0
# Stoke City	away	1	0	0	1	0	3
# Swansea City	home	0	1	0	2	2	1
# AFC Bournemouth	away	0	1	0	2	2	1
# Tottenham Hotspur	home	1	0	0	4	1	3
# West Ham United	away	0	0	1	1	4	0
# Watford FC	home	0	0	1	1	2	0
# Manchester United	away	1	0	0	2	1	3
# West Bromwich Albion	home	1	0	0	2	1	3
# Arsenal FC	away	0	0	1	1	2	0
# AFC Bournemouth	home	0	1	0	3	3	1
# Everton FC	away	0	1	0	3	3	1
# Aston Villa	home	0	0	1	2	3	0
# Watford FC	away	1	0	0	3	2	3
# Crystal Palace	home	1	0	0	5	1	3
# Newcastle United	away	0	0	1	1	5	0
# Leicester City	home	0	1	0	1	1	1
# Manchester United	away	0	1	0	1	1	1
# Liverpool FC	home	1	0	0	1	0	3
# Swansea City	away	0	0	1	0	1	0
# Manchester City	home	1	0	0	3	1	3
# Southampton FC	away	0	0	1	1	3	0
# Norwich City	home	0	1	0	1	1	1
# Arsenal FC	away	0	1	0	1	1	1
# Sunderland AFC	home	1	0	0	2	0	3
# Stoke City	away	0	0	1	0	2	0
# Tottenham Hotspur	home	0	1	0	0	0	1
# Chelsea FC	away	0	1	0	0	0	1
# West Ham United	home	0	1	0	1	1	1
# West Bromwich Albion	away	0	1	0	1	1	1
# Arsenal FC	home	1	0	0	3	1	3
# Sunderland AFC	away	0	0	1	1	3	0
# Chelsea FC	home	0	0	1	0	1	0
# AFC Bournemouth	away	1	0	0	1	0	3
# Everton FC	home	0	1	0	1	1	1
# Crystal Palace	away	0	1	0	1	1	1
# Manchester United	home	0	1	0	0	0	1
# West Ham United	away	0	1	0	0	0	1
# Newcastle United	home	1	0	0	2	0	3
# Liverpool FC	away	0	0	1	0	2	0
# Southampton FC	home	0	1	0	1	1	1
# Aston Villa	away	0	1	0	1	1	1
# Stoke City	home	1	0	0	2	0	3
# Manchester City	away	0	0	1	0	2	0
# Swansea City	home	0	0	1	0	3	0
# Leicester City	away	1	0	0	3	0	3
# Watford FC	home	1	0	0	2	0	3
# Norwich City	away	0	0	1	0	2	0
# West Bromwich Albion	home	0	1	0	1	1	1
# Tottenham Hotspur	away	0	1	0	1	1	1
# AFC Bournemouth	home	1	0	0	2	1	3
# Manchester United	away	0	0	1	1	2	0
# Aston Villa	home	0	0	1	0	2	0
# Arsenal FC	away	1	0	0	2	0	3
# Crystal Palace	home	1	0	0	1	0	3
# Southampton FC	away	0	0	1	0	1	0
# Leicester City	home	1	0	0	2	1	3
# Chelsea FC	away	0	0	1	1	2	0
# Liverpool FC	home	0	1	0	2	2	1
# West Bromwich Albion	away	0	1	0	2	2	1
# Manchester City	home	1	0	0	2	1	3
# Swansea City	away	0	0	1	1	2	0
# Norwich City	home	0	1	0	1	1	1
# Everton FC	away	0	1	0	1	1	1
# Sunderland AFC	home	0	0	1	0	1	0
# Watford FC	away	1	0	0	1	0	3
# Tottenham Hotspur	home	0	0	1	1	2	0
# Newcastle United	away	1	0	0	2	1	3
# West Ham United	home	0	1	0	0	0	1
# Stoke City	away	0	1	0	0	0	1
# Arsenal FC	home	1	0	0	2	1	3
# Manchester City	away	0	0	1	1	2	0
# Chelsea FC	home	1	0	0	3	1	3
# Sunderland AFC	away	0	0	1	1	3	0
# Everton FC	home	0	0	1	2	3	0
# Leicester City	away	1	0	0	3	2	3
# Manchester United	home	0	0	1	1	2	0
# Norwich City	away	1	0	0	2	1	3
# Newcastle United	home	0	1	0	1	1	1
# Aston Villa	away	0	1	0	1	1	1
# Southampton FC	home	0	0	1	0	2	0
# Tottenham Hotspur	away	1	0	0	2	0	3
# Stoke City	home	0	0	1	1	2	0
# Crystal Palace	away	1	0	0	2	1	3
# Swansea City	home	0	1	0	0	0	1
# West Ham United	away	0	1	0	0	0	1
# Watford FC	home	1	0	0	3	0	3
# Liverpool FC	away	0	0	1	0	3	0
# West Bromwich Albion	home	0	0	1	1	2	0
# AFC Bournemouth	away	1	0	0	2	1	3
# AFC Bournemouth	home	0	1	0	0	0	1
# Crystal Palace	away	0	1	0	0	0	1
# Aston Villa	home	0	1	0	1	1	1
# West Ham United	away	0	1	0	1	1	1
# Chelsea FC	home	0	1	0	2	2	1
# Watford FC	away	0	1	0	2	2	1
# Liverpool FC	home	1	0	0	1	0	3
# Leicester City	away	0	0	1	0	1	0
# Manchester City	home	1	0	0	4	1	3
# Sunderland AFC	away	0	0	1	1	4	0
# Newcastle United	home	0	0	1	0	1	0
# Everton FC	away	1	0	0	1	0	3
# Southampton FC	home	1	0	0	4	0	3
# Arsenal FC	away	0	0	1	0	4	0
# Stoke City	home	1	0	0	2	0	3
# Manchester United	away	0	0	1	0	2	0
# Swansea City	home	1	0	0	1	0	3
# West Bromwich Albion	away	0	0	1	0	1	0
# Tottenham Hotspur	home	1	0	0	3	0	3
# Norwich City	away	0	0	1	0	3	0
# Arsenal FC	home	1	0	0	2	0	3
# AFC Bournemouth	away	0	0	1	0	2	0
# Crystal Palace	home	0	1	0	0	0	1
# Swansea City	away	0	1	0	0	0	1
# Everton FC	home	0	0	1	3	4	0
# Stoke City	away	1	0	0	4	3	3
# Leicester City	home	0	1	0	0	0	1
# Manchester City	away	0	1	0	0	0	1
# Manchester United	home	0	1	0	0	0	1
# Chelsea FC	away	0	1	0	0	0	1
# Norwich City	home	1	0	0	2	0	3
# Aston Villa	away	0	0	1	0	2	0
# Sunderland AFC	home	0	0	1	0	1	0
# Liverpool FC	away	1	0	0	1	0	3
# Watford FC	home	0	0	1	1	2	0
# Tottenham Hotspur	away	1	0	0	2	1	3
# West Bromwich Albion	home	1	0	0	1	0	3
# Newcastle United	away	0	0	1	0	1	0
# West Ham United	home	1	0	0	2	1	3
# Southampton FC	away	0	0	1	1	2	0
# Arsenal FC	home	1	0	0	1	0	3
# Newcastle United	away	0	0	1	0	1	0
# Leicester City	home	0	1	0	0	0	1
# AFC Bournemouth	away	0	1	0	0	0	1
# Manchester United	home	1	0	0	2	1	3
# Swansea City	away	0	0	1	1	2	0
# Norwich City	home	1	0	0	1	0	3
# Southampton FC	away	0	0	1	0	1	0
# Sunderland AFC	home	1	0	0	3	1	3
# Aston Villa	away	0	0	1	1	3	0
# Watford FC	home	0	0	1	1	2	0
# Manchester City	away	1	0	0	2	1	3
# West Bromwich Albion	home	1	0	0	2	1	3
# Stoke City	away	0	0	1	1	2	0
# West Ham United	home	1	0	0	2	0	3
# Liverpool FC	away	0	0	1	0	2	0
# Crystal Palace	home	0	0	1	0	3	0
# Chelsea FC	away	1	0	0	3	0	3
# Everton FC	home	0	1	0	1	1	1
# Tottenham Hotspur	away	0	1	0	1	1	1
# AFC Bournemouth	home	0	0	1	1	3	0
# West Ham United	away	1	0	0	3	1	3
# Aston Villa	home	1	0	0	1	0	3
# Crystal Palace	away	0	0	1	0	1	0
# Liverpool FC	home	0	1	0	3	3	1
# Arsenal FC	away	0	1	0	3	3	1
# Swansea City	home	0	0	1	2	4	0
# Sunderland AFC	away	1	0	0	4	2	3
# Chelsea FC	home	0	1	0	2	2	1
# West Bromwich Albion	away	0	1	0	2	2	1
# Manchester City	home	0	1	0	0	0	1
# Everton FC	away	0	1	0	0	0	1
# Newcastle United	home	0	1	0	3	3	1
# Manchester United	away	0	1	0	3	3	1
# Southampton FC	home	1	0	0	2	0	3
# Watford FC	away	0	0	1	0	2	0
# Stoke City	home	1	0	0	3	1	3
# Norwich City	away	0	0	1	1	3	0
# Tottenham Hotspur	home	0	0	1	0	1	0
# Leicester City	away	1	0	0	1	0	3
# AFC Bournemouth	home	1	0	0	3	0	3
# Norwich City	away	0	0	1	0	3	0
# Aston Villa	home	0	1	0	1	1	1
# Leicester City	away	0	1	0	1	1	1
# Chelsea FC	home	0	1	0	3	3	1
# Everton FC	away	0	1	0	3	3	1
# Manchester City	home	1	0	0	4	0	3
# Crystal Palace	away	0	0	1	0	4	0
# Newcastle United	home	1	0	0	2	1	3
# West Ham United	away	0	0	1	1	2	0
# Southampton FC	home	1	0	0	3	0	3
# West Bromwich Albion	away	0	0	1	0	3	0
# Tottenham Hotspur	home	1	0	0	4	1	3
# Sunderland AFC	away	0	0	1	1	4	0
# Liverpool FC	home	0	0	1	0	1	0
# Manchester United	away	1	0	0	1	0	3
# Stoke City	home	0	1	0	0	0	1
# Arsenal FC	away	0	1	0	0	0	1
# Swansea City	home	1	0	0	1	0	3
# Watford FC	away	0	0	1	0	1	0
# Crystal Palace	home	0	0	1	1	3	0
# Tottenham Hotspur	away	1	0	0	3	1	3
# Leicester City	home	1	0	0	3	0	3
# Stoke City	away	0	0	1	0	3	0
# Manchester United	home	0	0	1	0	1	0
# Southampton FC	away	1	0	0	1	0	3
# Norwich City	home	0	0	1	4	5	0
# Liverpool FC	away	1	0	0	5	4	3
# Sunderland AFC	home	0	1	0	1	1	1
# AFC Bournemouth	away	0	1	0	1	1	1
# Watford FC	home	1	0	0	2	1	3
# Newcastle United	away	0	0	1	1	2	0
# West Bromwich Albion	home	0	1	0	0	0	1
# Aston Villa	away	0	1	0	0	0	1
# West Ham United	home	0	1	0	2	2	1
# Manchester City	away	0	1	0	2	2	1
# Arsenal FC	home	0	0	1	0	1	0
# Chelsea FC	away	1	0	0	1	0	3
# Everton FC	home	0	0	1	1	2	0
# Swansea City	away	1	0	0	2	1	3
# Arsenal FC	home	0	1	0	0	0	1
# Southampton FC	away	0	1	0	0	0	1
# Crystal Palace	home	0	0	1	1	2	0
# AFC Bournemouth	away	1	0	0	2	1	3
# Leicester City	home	1	0	0	2	0	3
# Liverpool FC	away	0	0	1	0	2	0
# Manchester United	home	1	0	0	3	0	3
# Stoke City	away	0	0	1	0	3	0
# Norwich City	home	0	0	1	0	3	0
# Tottenham Hotspur	away	1	0	0	3	0	3
# Sunderland AFC	home	0	0	1	0	1	0
# Manchester City	away	1	0	0	1	0	3
# Watford FC	home	0	1	0	0	0	1
# Chelsea FC	away	0	1	0	0	0	1
# West Bromwich Albion	home	0	1	0	1	1	1
# Swansea City	away	0	1	0	1	1	1
# West Ham United	home	1	0	0	2	0	3
# Aston Villa	away	0	0	1	0	2	0
# Everton FC	home	1	0	0	3	0	3
# Newcastle United	away	0	0	1	0	3	0
# Aston Villa	home	1	0	0	2	0	3
# Norwich City	away	0	0	1	0	2	0
# Liverpool FC	home	0	1	0	2	2	1
# Sunderland AFC	away	0	1	0	2	2	1
# Manchester City	home	0	0	1	1	3	0
# Leicester City	away	1	0	0	3	1	3
# Newcastle United	home	1	0	0	1	0	3
# West Bromwich Albion	away	0	0	1	0	1	0
# Stoke City	home	0	0	1	0	3	0
# Everton FC	away	1	0	0	3	0	3
# Swansea City	home	0	1	0	1	1	1
# Crystal Palace	away	0	1	0	1	1	1
# Tottenham Hotspur	home	1	0	0	1	0	3
# Watford FC	away	0	0	1	0	1	0
# AFC Bournemouth	home	0	0	1	0	2	0
# Arsenal FC	away	1	0	0	2	0	3
# Chelsea FC	home	0	1	0	1	1	1
# Manchester United	away	0	1	0	1	1	1
# Southampton FC	home	1	0	0	1	0	3
# West Ham United	away	0	0	1	0	1	0
# AFC Bournemouth	home	0	0	1	1	3	0
# Stoke City	away	1	0	0	3	1	3
# Chelsea FC	home	1	0	0	5	1	3
# Newcastle United	away	0	0	1	1	5	0
# Crystal Palace	home	0	0	1	1	2	0
# Watford FC	away	1	0	0	2	1	3
# Everton FC	home	0	0	1	0	1	0
# West Bromwich Albion	away	1	0	0	1	0	3
# Norwich City	home	0	1	0	2	2	1
# West Ham United	away	0	1	0	2	2	1
# Sunderland AFC	home	1	0	0	2	1	3
# Manchester United	away	0	0	1	1	2	0
# Swansea City	home	0	0	1	0	1	0
# Southampton FC	away	1	0	0	1	0	3
# Arsenal FC	home	1	0	0	2	1	3
# Leicester City	away	0	0	1	1	2	0
# Aston Villa	home	0	0	1	0	6	0
# Liverpool FC	away	1	0	0	6	0	3
# Manchester City	home	0	0	1	1	2	0
# Tottenham Hotspur	away	1	0	0	2	1	3
# Leicester City	home	1	0	0	1	0	3
# Norwich City	away	0	0	1	0	1	0
# Southampton FC	home	0	0	1	1	2	0
# Chelsea FC	away	1	0	0	2	1	3
# Stoke City	home	1	0	0	2	1	3
# Aston Villa	away	0	0	1	1	2	0
# Watford FC	home	0	1	0	0	0	1
# AFC Bournemouth	away	0	1	0	0	0	1
# West Bromwich Albion	home	1	0	0	3	2	3
# Crystal Palace	away	0	0	1	2	3	0
# West Ham United	home	1	0	0	1	0	3
# Sunderland AFC	away	0	0	1	0	1	0
# Liverpool FC	home	1	0	0	4	0	3
# Everton FC	away	0	0	1	0	4	0
# Manchester United	home	1	0	0	3	2	3
# Arsenal FC	away	0	0	1	2	3	0
# Newcastle United	home	0	1	0	1	1	1
# Manchester City	away	0	1	0	1	1	1
# Tottenham Hotspur	home	1	0	0	2	1	3
# Swansea City	away	0	0	1	1	2	0
# AFC Bournemouth	home	1	0	0	2	0	3
# Southampton FC	away	0	0	1	0	2	0
# Aston Villa	home	0	0	1	1	3	0
# Everton FC	away	1	0	0	3	1	3
# Leicester City	home	0	1	0	2	2	1
# West Bromwich Albion	away	0	1	0	2	2	1
# Norwich City	home	0	0	1	1	2	0
# Chelsea FC	away	1	0	0	2	1	3
# Sunderland AFC	home	0	1	0	2	2	1
# Crystal Palace	away	0	1	0	2	2	1
# Arsenal FC	home	0	0	1	1	2	0
# Swansea City	away	1	0	0	2	1	3
# Liverpool FC	home	1	0	0	3	0	3
# Manchester City	away	0	0	1	0	3	0
# Manchester United	home	1	0	0	1	0	3
# Watford FC	away	0	0	1	0	1	0
# Stoke City	home	1	0	0	1	0	3
# Newcastle United	away	0	0	1	0	1	0
# West Ham United	home	1	0	0	1	0	3
# Tottenham Hotspur	away	0	0	1	0	1	0
# Chelsea FC	home	0	1	0	1	1	1
# Stoke City	away	0	1	0	1	1	1
# Everton FC	home	0	0	1	2	3	0
# West Ham United	away	1	0	0	3	2	3
# Manchester City	home	1	0	0	4	0	3
# Aston Villa	away	0	0	1	0	4	0
# Newcastle United	home	0	0	1	1	3	0
# AFC Bournemouth	away	1	0	0	3	1	3
# Southampton FC	home	0	1	0	1	1	1
# Sunderland AFC	away	0	1	0	1	1	1
# Swansea City	home	1	0	0	1	0	3
# Norwich City	away	0	0	1	0	1	0
# Tottenham Hotspur	home	0	1	0	2	2	1
# Arsenal FC	away	0	1	0	2	2	1
# Watford FC	home	0	0	1	0	1	0
# Leicester City	away	1	0	0	1	0	3
# Crystal Palace	home	0	0	1	1	2	0
# Liverpool FC	away	1	0	0	2	1	3
# West Bromwich Albion	home	1	0	0	1	0	3
# Manchester United	away	0	0	1	0	1	0
# AFC Bournemouth	home	1	0	0	3	2	3
# Swansea City	away	0	0	1	2	3	0
# Arsenal FC	home	1	0	0	2	0	3
# West Bromwich Albion	away	0	0	1	0	2	0
# Aston Villa	home	0	0	1	0	2	0
# Tottenham Hotspur	away	1	0	0	2	0	3
# Manchester United	home	1	0	0	2	0	3
# Crystal Palace	away	0	0	1	0	2	0
# Norwich City	home	0	1	0	0	0	1
# Manchester City	away	0	1	0	0	0	1
# Stoke City	home	0	0	1	1	2	0
# Southampton FC	away	1	0	0	2	1	3
# Sunderland AFC	home	1	0	0	3	0	3
# Everton FC	away	0	0	1	0	3	0
# West Ham United	home	1	0	0	3	1	3
# Watford FC	away	0	0	1	1	3	0
# Liverpool FC	home	0	1	0	1	1	1
# Chelsea FC	away	0	1	0	1	1	1
# Leicester City	home	1	0	0	1	0	3
# Newcastle United	away	0	0	1	0	1	0
# Chelsea FC	home	0	1	0	2	2	1
# West Ham United	away	0	1	0	2	2	1
# Crystal Palace	home	0	0	1	0	1	0
# Leicester City	away	1	0	0	1	0	3
# Everton FC	home	0	0	1	0	2	0
# Arsenal FC	away	1	0	0	2	0	3
# Southampton FC	home	1	0	0	3	2	3
# Liverpool FC	away	0	0	1	2	3	0
# Swansea City	home	1	0	0	1	0	3
# Aston Villa	away	0	0	1	0	1	0
# Tottenham Hotspur	home	1	0	0	3	0	3
# AFC Bournemouth	away	0	0	1	0	3	0
# Watford FC	home	0	0	1	1	2	0
# Stoke City	away	1	0	0	2	1	3
# West Bromwich Albion	home	0	0	1	0	1	0
# Norwich City	away	1	0	0	1	0	3
# Manchester City	home	0	0	1	0	1	0
# Manchester United	away	1	0	0	1	0	3
# Newcastle United	home	0	1	0	1	1	1
# Sunderland AFC	away	0	1	0	1	1	1
# AFC Bournemouth	home	0	0	1	0	4	0
# Manchester City	away	1	0	0	4	0	3
# Arsenal FC	home	1	0	0	4	0	3
# Watford FC	away	0	0	1	0	4	0
# Aston Villa	home	0	0	1	0	4	0
# Chelsea FC	away	1	0	0	4	0	3
# Leicester City	home	1	0	0	1	0	3
# Southampton FC	away	0	0	1	0	1	0
# Liverpool FC	home	0	1	0	1	1	1
# Tottenham Hotspur	away	0	1	0	1	1	1
# Manchester United	home	1	0	0	1	0	3
# Everton FC	away	0	0	1	0	1	0
# Norwich City	home	1	0	0	3	2	3
# Newcastle United	away	0	0	1	2	3	0
# Stoke City	home	0	1	0	2	2	1
# Swansea City	away	0	1	0	2	2	1
# Sunderland AFC	home	0	1	0	0	0	1
# West Bromwich Albion	away	0	1	0	0	0	1
# West Ham United	home	0	1	0	2	2	1
# Crystal Palace	away	0	1	0	2	2	1
# Aston Villa	home	0	0	1	1	2	0
# AFC Bournemouth	away	1	0	0	2	1	3
# Crystal Palace	home	1	0	0	1	0	3
# Norwich City	away	0	0	1	0	1	0
# Liverpool FC	home	1	0	0	4	1	3
# Stoke City	away	0	0	1	1	4	0
# Manchester City	home	1	0	0	2	1	3
# West Bromwich Albion	away	0	0	1	1	2	0
# Southampton FC	home	1	0	0	3	1	3
# Newcastle United	away	0	0	1	1	3	0
# Sunderland AFC	home	0	0	1	0	2	0
# Leicester City	away	1	0	0	2	0	3
# Swansea City	home	1	0	0	1	0	3
# Chelsea FC	away	0	0	1	0	1	0
# Tottenham Hotspur	home	1	0	0	3	0	3
# Manchester United	away	0	0	1	0	3	0
# Watford FC	home	0	1	0	1	1	1
# Everton FC	away	0	1	0	1	1	1
# West Ham United	home	0	1	0	3	3	1
# Arsenal FC	away	0	1	0	3	3	1
# AFC Bournemouth	home	0	0	1	1	2	0
# Liverpool FC	away	1	0	0	2	1	3
# Arsenal FC	home	0	1	0	1	1	1
# Crystal Palace	away	0	1	0	1	1	1
# Chelsea FC	home	0	0	1	0	3	0
# Manchester City	away	1	0	0	3	0	3
# Everton FC	home	0	1	0	1	1	1
# Southampton FC	away	0	1	0	1	1	1
# Leicester City	home	0	1	0	2	2	1
# West Ham United	away	0	1	0	2	2	1
# Manchester United	home	1	0	0	1	0	3
# Aston Villa	away	0	0	1	0	1	0
# Newcastle United	home	1	0	0	3	0	3
# Swansea City	away	0	0	1	0	3	0
# Norwich City	home	0	0	1	0	3	0
# Sunderland AFC	away	1	0	0	3	0	3
# Stoke City	home	0	0	1	0	4	0
# Tottenham Hotspur	away	1	0	0	4	0	3
# West Bromwich Albion	home	0	0	1	0	1	0
# Watford FC	away	1	0	0	1	0	3
# AFC Bournemouth	home	0	0	1	1	4	0
# Chelsea FC	away	1	0	0	4	1	3
# Aston Villa	home	0	0	1	2	4	0
# Southampton FC	away	1	0	0	4	2	3
# Crystal Palace	home	0	1	0	0	0	1
# Everton FC	away	0	1	0	0	0	1
# Leicester City	home	1	0	0	4	0	3
# Swansea City	away	0	0	1	0	4	0
# Liverpool FC	home	0	1	0	2	2	1
# Newcastle United	away	0	1	0	2	2	1
# Manchester City	home	1	0	0	4	0	3
# Stoke City	away	0	0	1	0	4	0
# Norwich City	home	1	0	0	4	2	3
# Watford FC	away	0	0	1	2	4	0
# Sunderland AFC	home	0	1	0	0	0	1
# Arsenal FC	away	0	1	0	0	0	1
# Tottenham Hotspur	home	0	1	0	1	1	1
# West Bromwich Albion	away	0	1	0	1	1	1
# West Ham United	home	1	0	0	3	2	3
# Manchester United	away	0	0	1	2	3	0
# Arsenal FC	home	1	0	0	1	0	3
# Norwich City	away	0	0	1	0	1	0
# Chelsea FC	home	0	1	0	2	2	1
# Tottenham Hotspur	away	0	1	0	2	2	1
# Everton FC	home	1	0	0	2	1	3
# AFC Bournemouth	away	0	0	1	1	2	0
# Manchester United	home	0	1	0	1	1	1
# Leicester City	away	0	1	0	1	1	1
# Newcastle United	home	1	0	0	1	0	3
# Crystal Palace	away	0	0	1	0	1	0
# Southampton FC	home	1	0	0	4	2	3
# Manchester City	away	0	0	1	2	4	0
# Stoke City	home	0	1	0	1	1	1
# Sunderland AFC	away	0	1	0	1	1	1
# Swansea City	home	1	0	0	3	1	3
# Liverpool FC	away	0	0	1	1	3	0
# Watford FC	home	1	0	0	3	2	3
# Aston Villa	away	0	0	1	2	3	0
# West Bromwich Albion	home	0	0	1	0	3	0
# West Ham United	away	1	0	0	3	0	3
# AFC Bournemouth	home	0	1	0	1	1	1
# West Bromwich Albion	away	0	1	0	1	1	1
# Aston Villa	home	0	1	0	0	0	1
# Newcastle United	away	0	1	0	0	0	1
# Crystal Palace	home	1	0	0	2	1	3
# Stoke City	away	0	0	1	1	2	0
# Leicester City	home	1	0	0	3	1	3
# Everton FC	away	0	0	1	1	3	0
# Liverpool FC	home	1	0	0	2	0	3
# Watford FC	away	0	0	1	0	2	0
# Manchester City	home	0	1	0	2	2	1
# Arsenal FC	away	0	1	0	2	2	1
# Norwich City	home	0	0	1	0	1	0
# Manchester United	away	1	0	0	1	0	3
# Sunderland AFC	home	1	0	0	3	2	3
# Chelsea FC	away	0	0	1	2	3	0
# Tottenham Hotspur	home	0	0	1	1	2	0
# Southampton FC	away	1	0	0	2	1	3
# West Ham United	home	0	0	1	1	4	0
# Swansea City	away	1	0	0	4	1	3
# Arsenal FC	home	1	0	0	4	0	3
# Aston Villa	away	0	0	1	0	4	0
# Chelsea FC	home	0	1	0	1	1	1
# Leicester City	away	0	1	0	1	1	1
# Everton FC	home	1	0	0	3	0	3
# Norwich City	away	0	0	1	0	3	0
# Manchester United	home	1	0	0	3	1	3
# AFC Bournemouth	away	0	0	1	1	3	0
# Newcastle United	home	1	0	0	5	1	3
# Tottenham Hotspur	away	0	0	1	1	5	0
# Southampton FC	home	1	0	0	4	1	3
# Crystal Palace	away	0	0	1	1	4	0
# Stoke City	home	1	0	0	2	1	3
# West Ham United	away	0	0	1	1	2	0
# Swansea City	home	0	1	0	1	1	1
# Manchester City	away	0	1	0	1	1	1
# Watford FC	home	0	1	0	2	2	1
# Sunderland AFC	away	0	1	0	2	2	1
# West Bromwich Albion	home	0	1	0	1	1	1
# Liverpool FC	away	0	1	0	1	1	1

# %%
get_sum = lambda x,y: x+y
    
def process_games(games):
    num_won = reduce(get_sum, map(lambda game_result: int(game_result[2]), games))
    num_draw = reduce(get_sum, map(lambda game_result: int(game_result[3]), games))
    num_lost = reduce(get_sum, map(lambda game_result: int(game_result[4]), games))
    num_scored = reduce(get_sum, map(lambda game_result: int(game_result[5]), games))
    num_conceded = reduce(get_sum, map(lambda game_result: int(game_result[6]), games))
    num_points = reduce(get_sum, map(lambda game_result: int(game_result[7]), games))
    return [num_won, num_draw, num_lost, num_scored, num_conceded, num_points]
    
def get_scored_conceded(a_list):
    return [str(a_list[3])+ ":" + str(a_list[4])]

def process_team_games(teamgames):
    team = teamgames[0][0]
#     [team, where, win, draw, lose, goals_scored, goals_conceded, points]
    home_games = filter(lambda a_game: a_game[1] == "home", teamgames)
    away_games = filter(lambda a_game: a_game[1] == "away", teamgames)
    num_played = str(len(teamgames))
    
    home_results = [h_num_won, h_num_draw, h_num_lost, h_num_scored, h_num_conceded, h_num_points] = process_games(home_games)
    away_results = [a_num_won, a_num_draw, a_num_lost, a_num_scored, a_num_conceded, a_num_points] = process_games(away_games)
    total_scored = h_num_scored + a_num_scored
    total_conceded = h_num_conceded + a_num_conceded
    total_points = h_num_points + a_num_points
    
    printable = [team,num_played]
    printable.extend(home_results[:3])
    printable.extend(get_scored_conceded(home_results))
    printable.extend(away_results[:3])
    printable.extend(get_scored_conceded(away_results))
    printable.extend([str(h_num_scored+a_num_scored)+":"+str(h_num_conceded+a_num_conceded)])
    printable.extend([str(total_scored-total_conceded), str(total_points)])
    print "\t".join(map(lambda col: str(col), printable))
                                                             
    
current_team = None
games_of_a_team = []
for line in open("mapper_output.txt","r"):
    [team, where, win, draw, lose, goals_scored, goals_conceded, points] = line.strip().split("\t")
    if not current_team:
        current_team = team
    if team == current_team:
        games_of_a_team.append([team, where, win, draw, lose, goals_scored, goals_conceded, points])
    else:
        process_team_games(games_of_a_team)
        current_team = team
        games_of_a_team = []
process_team_games(games_of_a_team)
# Out:
# AFC Bournemouth	38	5	5	9	23:34	6	4	9	22:33	45:67	-22	42
# Arsenal FC	37	12	4	3	31:11	8	7	3	34:23	65:34	31	71
# Aston Villa	37	2	5	12	14:35	1	3	14	13:40	27:75	-48	17
# Chelsea FC	37	5	9	5	32:30	7	5	6	27:22	59:52	7	50
# Crystal Palace	37	6	3	10	19:23	5	6	7	20:27	39:50	-11	42
# Everton FC	37	6	5	8	35:30	5	9	4	24:24	59:54	5	47
# Leicester City	37	12	6	1	35:18	11	6	1	33:17	68:35	33	81
# Liverpool FC	37	8	8	3	33:22	8	4	6	30:26	63:48	15	60
# Manchester City	37	12	2	5	47:21	7	7	4	24:18	71:39	32	66
# Manchester United	37	12	5	2	27:9	7	4	7	22:25	49:34	15	66
# Newcastle United	37	7	7	5	32:24	2	3	13	12:40	44:64	-20	37
# Norwich City	37	6	5	8	26:30	3	2	13	13:36	39:66	-27	34
# Southampton FC	37	11	3	5	39:22	7	6	5	20:18	59:40	19	63
# Stoke City	37	8	4	7	22:24	6	5	7	19:29	41:53	-12	51
# Sunderland AFC	37	6	6	7	23:20	3	6	9	25:41	48:61	-13	39
# Swansea City	37	8	6	5	20:20	4	5	9	22:31	42:51	-9	47
# Tottenham Hotspur	37	10	6	3	35:15	9	7	2	34:19	69:34	35	70
# Watford FC	37	6	6	7	20:19	6	3	9	20:30	40:49	-9	45
# West Bromwich Albion	37	6	5	8	20:26	4	8	6	14:21	34:47	-13	43
# West Ham United	37	9	7	3	34:26	7	7	4	31:24	65:50	15	62
